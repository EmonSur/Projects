# %% [markdown]
# # Markdown Cells

# %% [markdown]
# Write a markdown cell with the following:
#
# 1. A bullet list of five names.
# 2. Add a link to a webpage for the first name
# 3. Add an enumerated sublist of three drinks to the second name.
# 4. make the other names in bold, italic and typewriter font.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# # Typeset Formulas

# %% [markdown]
# 1. Typeset the formula for the volume of a sphere in inline mode

# %% [markdown]
# \begin{equation}
# U_{AA}
# \end{equation}

# %% [markdown]
# 2. Typset the [Black Scholes equation](https://en.wikipedia.org/wiki/Black%E2%80%93Scholes_model#Black%E2%80%93Scholes_equation) from Financial Maths in display style (i.e. using `\begin{equation} ... \end{equation}`).  ![black.svg](attachment:black.svg)
#
# (Hint: use `\partial` for $\partial$)
#
# Remark: Wikipedia of course also uses LaTeX for its formulas (although it does not use markdown).  You can see the LaTeX code when you look at the html code (Ctrl-u) or go to "edit" on top of the page.

# %% [markdown]
# \begin{equation}
# \frac{\partial V}{\partial t} + \frac{1}{2} {\sigma}^2{S}^2
# \end{equation}

# %% [markdown]
# 3. Typeset the formula for the [normal Gaussian distribution](http://en.wikipedia.org/wiki/Normal_distribution) in display style. Hint: if you are stuck, you can right click on any formula on wikipedia and then select "View image info". This will show the LaTeX code under "Associated text".

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# 4. Now also try  ![T05_f1.png](attachment:T05_f1.png)
#
# Hint: Use `\int` for the integral.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# 5. Now  ![T05_f2.png](attachment:T05_f2.png)
# Hints: Use `\sum` for the sum and `\tilde{P}` to get $\tilde{P}$. The angles at the right are obtained with `\rangle` (not `>`).

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# 6. Here an example with matrices:
# ![fig2.png](attachment:fig2.png)

# %% [markdown]
# \begin{equation}
# \left(
#     \begin{array}{cc}
#     x & y \\
#     z & w
#     \end{array}
# \right)
# \end{equation}

# %% [markdown]
# \begin{equation}
# \left(
#     \begin{array}{cc}
#      U_{AA}^{-1} & U_{AB}^{-1} \\
#      U_{BA}^{-1} & U_{BB}^{-1}
#     \end{array}
# \right)
# \left(
#     \begin{array}{c}
#      x \\
#      y
#     \end{array}
# \right)
# \end{equation}

# %% [markdown]
# \begin{equation}
# \left(
#     \begin{array}{c}
#     x \\
#     y
#     \end{array}
# \right)
# \end{equation}

# %% [markdown]
# 7. Finally another nice one: ![fig1.png](attachment:fig1.png)
#
# Hints: use `\|` for $\|$, `\wedge` for $\wedge$ and `\pm` for $\pm$

# %% [markdown]
# YOUR ANSWER HERE
